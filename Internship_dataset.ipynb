# %% [markdown]
# <a href="https://colab.research.google.com/github/Shamaanjum-26/intern_performance_analytics_dataset/blob/main/Internship_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

num_records = 100


intern_names = [
"Arun Kumar","Karthik Raja","Vignesh Kumar","Sathish Kumar","Prakash Raj",
"Senthil Kumar","Saravanan","Dinesh Kumar","Ramesh Kumar","Suresh Kumar",
"Balaji","Manikandan","Murugan","Raja","Rajkumar",
"Praveen Kumar","Vijay Kumar","Ajith Kumar","Karthikeyan","Logesh",
"Harish Kumar","Gokul","Naveen Kumar","Kishore Kumar","Deepak Kumar",
"Aravind","Bharath Kumar","Chandru","Dhinesh","Elango",
"Ganesh Kumar","Hariharan","Ilayaraja","Jagan","Kamal Kumar",
"Lakshman","Madhan","Nandakumar","Prabhakaran","Rajasekar",
"Sakthivel","Sathyaraj","Selvam","Shankar","Sivakumar",
"Sudhakar","Thirumal","Udhay Kumar","Velmurugan","Yogesh",
"Abinaya","Anitha","Divya","Gayathri","Harini",
"Janani","Kavitha","Keerthana","Lavanya","Madhumitha",
"Nandhini","Pavithra","Priyadharshini","Revathi","Roshini",
"Sangeetha","Sharmila","Shobana","Sindhu","Sneha",
"Sowmya","Suganya","Swathi","Tamilselvi","Uma Maheswari",
"Vasuki","Vidhya","Vinodhini","Yamini","Aarthi",
"Aishwarya","Akshaya","Anupriya","Bhavani","Chitra",
"Deepika","Durga","Geetha","Indhu","Jeevitha",
"Kavya","Kowsalya","Meena","Nivetha","Poornima",
"Preethi","Ramya","Sathya","Shalini","Varsha"
]

colleges = [
"Anna University",
"University of Madras",
"Madurai Kamaraj University",
"Bharathiar University",
"Bharathidasan University",
"SRM Institute of Science and Technology",
"VIT Chennai",
"KSR College of Technology",
"Sathyabama Institute of Science and Technology",
"PSG College of Technology",
"Thiagarajar College of Engineering",
"Kumaraguru College of Technology",
"Kongu Engineering College",
"Coimbatore Institute of Technology",
"St Joseph's College Trichy",
"Loyola College Chennai",
"SSN College of Engineering",
"Velammal Engineering College",
"Rajalakshmi Engineering College",
"Saveetha Engineering College",
"Amrita Vishwa Vidyapeetham Coimbatore"
]

data = {
"Intern_ID": range(1, num_records+1),
"Intern_Name": np.random.choice(intern_names, num_records),
"Age": np.random.randint(20,25,num_records),
"Gender": np.random.choice(["Male","Female"],num_records),
"College_Name": np.random.choice(colleges,num_records),
"Degree": np.random.choice(["B.Tech","B.Sc","BCA","MCA"],num_records),
"Department": np.random.choice(["Data Science","Data Analyst","AI","Full Stack","Cloud"],num_records),
"City": np.random.choice(["Chennai","Coimbatore","Madurai","Trichy","Salem","Erode"],num_records),
"Internship_Mode": np.random.choice(["Remote","Hybrid","Onsite"],num_records),
"Internship_Duration_Months": np.random.choice([1,2,3,6],num_records),
"Project_Assigned": np.random.choice(["Intern Insight Dashboard","Sales Analytics","ML Prediction Model","Data Visualization","Customer Analysis"],num_records),
"Mentor_Name": np.random.choice(["Ravi","Prakash","Karthik","Suresh","Anand"],num_records),
"Tasks_Assigned": np.random.randint(10,40,num_records),
"Tasks_Completed": np.random.randint(5,35,num_records),
"Attendance_Percentage": np.random.randint(70,100,num_records),
"Late_Submissions": np.random.randint(0,5,num_records),
"Meetings_Attended": np.random.randint(5,20,num_records),
"Communication_Score": np.random.randint(1,6,num_records),
"Technical_Score": np.random.randint(1,6,num_records),
"Teamwork_Score": np.random.randint(1,6,num_records),
"Problem_Solving_Score": np.random.randint(1,6,num_records),
"Final_Performance_Rating": np.random.randint(1,6,num_records),
"Certificate_Eligible": np.random.choice(["Yes","No"],num_records),
"Placement_Recommended": np.random.choice(["Yes","No"],num_records),
"Stipend": np.random.choice([0,5000,8000,10000],num_records)
}

df = pd.DataFrame(data)

print(df.head())
print(df.shape)

df.to_csv("intern_insight_dataset.csv", index=False)

from google.colab import files
files.download("intern_insight_dataset.csv")
# Out:
#    Intern_ID Intern_Name  Age  Gender                  College_Name Degree  \
# 0          1    Rajkumar   22  Female  Saveetha Engineering College    MCA
# 1          2   Sivakumar   21  Female  Saveetha Engineering College   B.Sc
# 2          3   Aishwarya   24  Female  Saveetha Engineering College    BCA
# 3          4   Ilayaraja   22    Male                   VIT Chennai   B.Sc
# 4          5     Roshini   22  Female    SSN College of Engineering   B.Sc
#
#      Department     City Internship_Mode  Internship_Duration_Months  ...  \
# 0  Data Science    Erode          Hybrid                           6  ...
# 1         Cloud    Salem          Hybrid                           6  ...
# 2  Data Science    Erode          Hybrid                           1  ...
# 3    Full Stack  Chennai          Remote                           6  ...
# 4         Cloud  Madurai          Hybrid                           2  ...
#
# ...
